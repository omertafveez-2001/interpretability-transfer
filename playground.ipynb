# %%
import pandas as pd
from utils import plot_layer_bits_multi_frac, plot_layer, plot_model_grid

# %%
plot_layer("btlm", "layer15")
# Out:
# <Axes: title={'center': 'Steering Effect on Hermes BTLM-3b — Layer 15'}, xlabel='Multiplier', ylabel='Difference in the probability of the behavior'>

# %%
ax = plot_layer_bits_multi_frac("tuned-lens/results/tuned_lens_bpb", title="Tuned Lens Bits Per Logit")

# %%
# Single layer: model_name + layer folder name
plot_model_grid("llama");

# %%
# All layers for a model in a grid
plot_model_grid("btlm");

# %%
plot_model_grid("rwkv");

# %%
plot_model_grid("mamba");
